# %%
def menu_select(mesa, comensal, entrada, medio, fuerte, adicionales):
    print(f"Detalle:    ")
    print(f"\t\t\tMESA:{mesa}")
    print(f"\t\t\tCOMENSAL:{comensal}")
    print(f"\t\t\tENTRADA:{entrada}")
    print(f"\t\t\tMEDIO:{medio}")
    print(f"\t\t\tFUERTE:{fuerte}")
    print(f"\t\t\tADICIONALES:{adicionales}")
menu_select( mesa=3, comensal=2, entrada="Ensalada verde", medio="crema de zanahoria", fuerte="filete", adicionales="Filete termino medio,\n la ensalada sin ningun tipo de semilla, Adereso\n Ranch")
